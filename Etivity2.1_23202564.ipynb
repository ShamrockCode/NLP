# %% [markdown]
# Name: Feiyang Li
# ID: 23202564

# %% [markdown]
# # Task 1:

# %%
import time

#How many insertions, deletions, or substitutions does it take to turn x into y?
def edDistRecursive(x, y):

    # If either x or y are empty, then one or more (depending on their length) INSERTIONS or DELECTIONS are needed to transform x to y.
    if len(x) == 0:
        #print(f'\t Converting "{x}" TO "{y}" requires {len(y)} INSERTIONS, therefor it costs {len(y)}')
        return len(y)
    if len(y) == 0:
        #print(f'\t Converting "{x}" TO "{y}" requires {len(x)} DELETIONS, therefor it costs {len(x)}')
        return len(x)

    # When neither x or y are empty, we must compute the cost of each operation and find the least costly one.
    delta = 1 if x[-1] != y[-1] else 0
    if x[-1].isalpha() and y[-1].isdigit():  # Check if substitution involves a letter and a number
        delta = 2
    diagonal_or_substitution_cost = edDistRecursive(x[:-1], y[:-1]) + delta #what's the cost of SUBSTITUTING the last character of x with the last character of y
    vertical_or_deletion_cost = edDistRecursive(x[:-1], y) + 1     #what's the cost of DELETING the last character of x
    horizontal_or_insertion_cost = edDistRecursive(x, y[:-1]) + 1     #what's the cost of INSERTING the last character of x into y

    # what's the least costly operation?
    minValue = min(diagonal_or_substitution_cost, vertical_or_deletion_cost, horizontal_or_insertion_cost)
    return minValue

x = "intention"
y = "execution"
start_time = time.time()
result = edDistRecursive(x,y)
end_time = time.time()
print('Edit Distance between "{0}" and "{1}" is: {2}'.format(str(x),str(y),result))
print('--- Executed in: {0} seconds ---'.format(end_time - start_time))
# Out:
# Edit Distance between "intention" and "execution" is: 5
# --- Executed in: 1.002363920211792 seconds ---

# %% [markdown]
# # Task 2:

# %%
# !pip install names-dataset
# !pip install jellyfish

# %%
import names_dataset
from names_dataset import NameDataset, NameWrapper
import jellyfish

# %%
firstName = "Fiona"
lastName = "Li"

# %% [markdown]
# ## A

# %%
def check_names_in_dataset(firstName, lastName):
    nd = NameDataset()

    # To check if names in dataset
    if nd.search(firstName) and nd.search(lastName):
        return True
    else:
        return False


if check_names_in_dataset(firstName, lastName):
    print(f"Last name '{firstName}' and First name '{lastName}' exist.")
else:
    print(f"Last name '{firstName}' and First name '{lastName}' don't exist.")
# Out:
# Last name 'Fiona' and First name 'Li' exist.

# %% [markdown]
# ## B

# %%
def get_soundex(firstName, lastName):
   print(jellyfish.soundex(firstName))
   print(jellyfish.soundex(lastName))

get_soundex(firstName, lastName)
# Out:
# F500
# L000

# %% [markdown]
# ## C

# %%
def get_soundex_code(name):
    return jellyfish.soundex(name)

def find_matching_soundex_names(firstName):
    target_soundex = get_soundex_code(firstName)
    matching_names = []
    nd = NameDataset()
    names_list = list(nd.first_names.keys())

    for name in names_list:
        if get_soundex_code(name) == target_soundex:
            matching_names.append(name)

    return matching_names



matching_names = find_matching_soundex_names(firstName)
print(f"First names with the same Soundex code as '{firstName}':")
print(matching_names)
# Out:
# First names with the same Soundex code as 'Fiona':
# ...

# %% [markdown]
# ## D

# %%
def Ldistance(firstName,lastName):
  return jellyfish.levenshtein_distance(firstName, lastName)

print(Ldistance(firstName,lastName))
# Out:
# 4
